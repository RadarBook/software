# %% [markdown]
# # ***Introduction to Radar Using Python and MATLAB***
# ## Andy Harrison - Copyright (C) 2019 Artech House
# <br/>
#
# # Single Pulse Ambiguity Function
# ***

# %% [markdown]
# Referring to Section 8.6.1, the complex envelope of a single unmodulated pulse is expressed as (Equation 8.59)
#
# \begin{equation}\label{eq:single_unmodulated_pulse}
#     s(t) = \text{rect}\bigg[ \frac{t}{\tau_p} \bigg],
# \end{equation}
#
#
# \noindent Using (Equation 8.59) and (Equation 8.53) allows the ambiguity function to be written as (Equation 8.61)
#
# \begin{equation}
#     \big| \chi(\tau, f) \big|^2  = \Bigg| \int\limits_{-\infty}^{\infty} \text{rect}\bigg[ \frac{t}{\tau_p}\bigg] \, \text{rect}\bigg[ \frac{t - \tau}{\tau_p} \bigg] e^{j 2 \pi f t}\, dt\Bigg|^2.
# \end{equation}
#
# Carrying out the integration gives (Equation 8.62)
#
# \begin{equation}
#     \big| \chi(\tau, f) \big|^2  = (\tau_p - |\tau|)^2\, \Big|\text{sinc}\left[ f (\tau_p - |\tau|) \right]  \Big|^2 \quad \text{for  } |\tau| \le \tau_p.
# \end{equation}
# ***

# %% [markdown]
# Begin by getting the library path

# %%
import lib_path

# %% [markdown]
# Set the pulsewidth (s)

# %%
pulsewidth = 1e-3

# %% [markdown]
# Generate the time delay (s) using the `linspace` routine from `scipy`

# %%
from numpy import linspace


# Set the time delay

time_delay = linspace(-pulsewidth, pulsewidth, 5000)

# %% [markdown]
# Calculate the ambiguity function for the single pulse

# %%
from Libs.ambiguity.ambiguity_function import single_pulse

from numpy import finfo


ambiguity = single_pulse(time_delay, finfo(float).eps, pulsewidth)

# %% [markdown]
# Plot the zero-Doppler cut using the `matplotlib` routines

# %%
from matplotlib import pyplot as plt


# Set the figure size

plt.rcParams["figure.figsize"] = (15, 10)



# Plot the ambiguity function

plt.plot(time_delay, ambiguity, '')



# Set the x and y axis labels

plt.xlabel("Time (s)", size=12)

plt.ylabel("Relative Amplitude", size=12)



# Turn on the grid

plt.grid(linestyle=':', linewidth=0.5)



# Set the plot title and labels

plt.title('Single Pulse Ambiguity Function', size=14)



# Set the tick label size

plt.tick_params(labelsize=12)

# %% [markdown]
# Set the Doppler mismatch frequencies using the `linspace` routine

# %%
doppler_frequency = linspace(-2.0 / pulsewidth, 2.0 / pulsewidth, 1000)

# %% [markdown]
# Calculate the ambiguity function for the single pulse

# %%
ambiguity = single_pulse(finfo(float).eps, doppler_frequency, pulsewidth)

# %% [markdown]
# Display the zero-range cut for the single pulse

# %%
plt.plot(doppler_frequency, ambiguity, '')


# Set the x and y axis labels

plt.xlabel("Doppler (Hz)", size=12)

plt.ylabel("Relative Amplitude", size=12)



# Turn on the grid

plt.grid(linestyle=':', linewidth=0.5)



# Set the plot title and labels

plt.title('Single Pulse Ambiguity Function', size=14)



# Set the tick label size

plt.tick_params(labelsize=12)

# %% [markdown]
# Set the time delay and Doppler mismatch frequency and create the two-dimensional grid using the `meshgrid` routine from `scipy`

# %%
from numpy import meshgrid


# Set the time delay

time_delay = linspace(-pulsewidth, pulsewidth, 1000)



# Set the Doppler mismatch

doppler_frequency =linspace(-2.0 / pulsewidth, 2.0 / pulsewidth, 1000)



# Create the grid

t, f = meshgrid(time_delay, doppler_frequency)

# %% [markdown]
# Calculate the ambiguity function for the single pulse

# %%
ambiguity = single_pulse(t, f, pulsewidth)

# %% [markdown]
# Display the two-dimensional contour plot for the single pulse ambiguity function

# %%
# Plot the ambiguity function

plt.contour(t, f, ambiguity, 20, cmap='jet', vmin=-0.2, vmax=1.0)


# Set the x and y axis labels

plt.xlabel("Time (s)", size=12)

plt.ylabel("Doppler (Hz)", size=12)



# Turn on the grid

plt.grid(linestyle=':', linewidth=0.5)



# Set the plot title and labels

plt.title('Single Pulse Ambiguity Function', size=14)



# Set the tick label size

plt.tick_params(labelsize=12)
